# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("credit_scoring.csv")
print(data.head())
# Out:
#    Age  Gender Marital Status Education Level Employment Status  \
# 0   60    Male        Married          Master          Employed
# 1   25    Male        Married     High School        Unemployed
# 2   30  Female         Single          Master          Employed
# 3   58  Female        Married             PhD        Unemployed
# 4   32    Male        Married        Bachelor     Self-Employed
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      0.22           2685.0                          2
# 1                      0.20           2371.0                          9
# 2                      0.22           2771.0                          6
# 3                      0.12           1371.0                          2
# 4                      0.99            828.0                          2
#
#    Loan Amount  Interest Rate  Loan Term   Type of Loan
# 0      4675000           2.65         48  Personal Loan
# 1      3619000           5.19         60      Auto Loan
# 2       957000           2.76         12      Auto Loan
# 3      4731000           6.57         60      Auto Loan
# 4      3289000           6.28         36  Personal Loan

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        1000 non-null   int64
#  1   Gender                     1000 non-null   object
#  2   Marital Status             1000 non-null   object
#  3   Education Level            1000 non-null   object
#  4   Employment Status          1000 non-null   object
#  5   Credit Utilization Ratio   1000 non-null   float64
#  6   Payment History            1000 non-null   float64
#  7   Number of Credit Accounts  1000 non-null   int64
#  8   Loan Amount                1000 non-null   int64
#  9   Interest Rate              1000 non-null   float64
#  10  Loan Term                  1000 non-null   int64
#  11  Type of Loan               1000 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB
# None

# %%
print(data.describe())
# Out:
#                Age  Credit Utilization Ratio  Payment History  \
# count  1000.000000               1000.000000      1000.000000
# mean     42.702000                  0.509950      1452.814000
# std      13.266771                  0.291057       827.934146
# min      20.000000                  0.000000         0.000000
# 25%      31.000000                  0.250000       763.750000
# 50%      42.000000                  0.530000      1428.000000
# 75%      54.000000                  0.750000      2142.000000
# max      65.000000                  1.000000      2857.000000
#
#        Number of Credit Accounts   Loan Amount  Interest Rate    Loan Term
# count                1000.000000  1.000000e+03    1000.000000  1000.000000
# mean                    5.580000  2.471401e+06      10.686600    37.128000
# std                     2.933634  1.387047e+06       5.479058    17.436274
# min                     1.000000  1.080000e+05       1.010000    12.000000
# 25%                     3.000000  1.298000e+06       6.022500    24.000000
# 50%                     6.000000  2.437500e+06      10.705000    36.000000
# 75%                     8.000000  3.653250e+06      15.440000    48.000000
# max                    10.000000  4.996000e+06      19.990000    60.000000

# %%
education_level_mapping = {'High School': 1, 'Bachelor': 2, 'Master': 3, 'PhD': 4}
employment_status_mapping = {'Unemployed': 0, 'Employed': 1, 'Self-Employed': 2}
data['Education Level'] = data['Education Level'].map(education_level_mapping)
data['Employment Status'] = data['Employment Status'].map(employment_status_mapping)


credit_scores = []

for index, row in data.iterrows():
    payment_history = row['Payment History']
    credit_utilization_ratio = row['Credit Utilization Ratio']
    number_of_credit_accounts = row['Number of Credit Accounts']
    education_level = row['Education Level']
    employment_status = row['Employment Status']

    credit_score = (payment_history * 0.35) + (credit_utilization_ratio * 0.30) + (number_of_credit_accounts * 0.15) + (education_level * 0.10) + (employment_status * 0.10)
    credit_scores.append(credit_score)

data['Credit Score'] = credit_scores

print(data.head())
# Out:
#    Age  Gender Marital Status  Education Level  Employment Status  \
# 0   60    Male        Married                3                  1
# 1   25    Male        Married                1                  0
# 2   30  Female         Single                3                  1
# 3   58  Female        Married                4                  0
# 4   32    Male        Married                2                  2
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      0.22           2685.0                          2
# 1                      0.20           2371.0                          9
# 2                      0.22           2771.0                          6
# 3                      0.12           1371.0                          2
# 4                      0.99            828.0                          2
#
#    Loan Amount  Interest Rate  Loan Term   Type of Loan  Credit Score
# 0      4675000           2.65         48  Personal Loan       940.516
# 1      3619000           5.19         60      Auto Loan       831.360
# 2       957000           2.76         12      Auto Loan       971.216
# 3      4731000           6.57         60      Auto Loan       480.586
# 4      3289000           6.28         36  Personal Loan       290.797

# %% [markdown]
# *MODEL*

# %%
data.head()
# Out:
#    Age  Gender Marital Status  Education Level  Employment Status  \
# 0   60    Male        Married                3                  1
# 1   25    Male        Married                1                  0
# 2   30  Female         Single                3                  1
# 3   58  Female        Married                4                  0
# 4   32    Male        Married                2                  2
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      0.22           2685.0                          2
# 1                      0.20           2371.0                          9
# 2                      0.22           2771.0                          6
# 3                      0.12           1371.0                          2
# 4                      0.99            828.0                          2
#
#    Loan Amount  Interest Rate  Loan Term   Type of Loan  Credit Score
# 0      4675000           2.65         48  Personal Loan       940.516
# 1      3619000           5.19         60      Auto Loan       831.360
# 2       957000           2.76         12      Auto Loan       971.216
# 3      4731000           6.57         60      Auto Loan       480.586
# 4      3289000           6.28         36  Personal Loan       290.797

# %%
data['Gender'] = data['Gender'].map({
    'Male':1,
    'Female':0
})
data['Marital Status'] = data['Marital Status'].map({
    'Married':1,
    'Single':0
})
data['Marital Status'] = data['Marital Status'].fillna(1)
data['Type of Loan'] = data['Type of Loan'].map({
    'Personal Loan':1, 'Auto Loan':2, 'Home Loan':3
})

# %%
data["Credit Utilization Ratio"] = [x * 100 for x in data["Credit Utilization Ratio"]]

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras.losses import Huber
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
x = data[['Age','Gender','Marital Status','Education Level','Employment Status','Credit Utilization Ratio','Payment History','Number of Credit Accounts','Loan Amount','Interest Rate','Loan Term','Type of Loan']]
y = data['Credit Score']

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.20)

# %%
model = Sequential([
    Dense(128, input_shape=(xtrain.shape[1],), activation='relu', kernel_regularizer=keras.regularizers.L2(0.01)),
    BatchNormalization(),  
    Dropout(0.4),
    
    Dense(64, activation='relu', kernel_regularizer=keras.regularizers.L2(0.01)),
    BatchNormalization(),
    Dropout(0.3),
    
    Dense(32, activation='relu', kernel_regularizer=keras.regularizers.L2(0.01)),
    BatchNormalization(),
    Dropout(0.2),

    Dense(16, activation='relu', kernel_regularizer=keras.regularizers.L2(0.01)),
    BatchNormalization(),
    Dropout(0.1),

    Dense(1, activation='linear') 
])
# Out:
# c:\Users\KIRAN\Documents\Finage(AI)\venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer = AdamW(learning_rate=0.001, weight_decay=1e-4)  
model.compile(optimizer=optimizer, loss=keras.losses.Huber(), metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,505 (52.75 KB)
#  Trainable params: 13,025 (50.88 KB)
#  Non-trainable params: 480 (1.88 KB)

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
]

# %%
history = model.fit(xtrain, ytrain, epochs=200, batch_size=16, validation_data=(xtest, ytest), callbacks=callbacks)
# Out:
# Epoch 1/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 525.1424 - mae: 524.0705 - val_loss: 476.8301 - val_mae: 476.0678 - learning_rate: 0.0010
# Epoch 2/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 513.5942 - mae: 512.8981 - val_loss: 462.9958 - val_mae: 462.4559 - learning_rate: 0.0010
# Epoch 3/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 520.0596 - mae: 519.5562 - val_loss: 462.1780 - val_mae: 461.7558 - learning_rate: 0.0010
# Epoch 4/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 515.8840 - mae: 515.4846 - val_loss: 461.6349 - val_mae: 461.2867 - learning_rate: 0.0010
# Epoch 5/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 512.5844 - mae: 512.2507 - val_loss: 461.0364 - val_mae: 460.7391 - learning_rate: 0.0010
# Epoch 6/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 526.4193 - mae: 526.1338 - val_loss: 459.2938 - val_mae: 459.0374 - learning_rate: 0.0010
# Epoch 7/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 527.2430 - mae: 526.9951 - val_loss: 458.2921 - val_mae: 458.0677 - learning_rate: 0.0010
# Epoch 8/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 518.9401 - mae: 518.7221 - val_loss: 456.8454 - val_mae: 456.6463 - learning_rate: 0.0010
# Epoch 9/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 521.6871 - mae: 521.4937 - val_loss: 454.7066 - val_mae: 454.5289 - learning_rate: 0.0010
# Epoch 10/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 502.2641 - mae: 502.0915 - val_loss: 452.2524 - val_mae: 452.0931 - learning_rate: 0.0010
# Epoch 11/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 501.5952 - mae: 501.4396 - val_loss: 448.5766 - val_mae: 448.4324 - learning_rate: 0.0010
# Epoch 12/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 514.8040 - mae: 514.6638 - val_loss: 445.3995 - val_mae: 445.2693 - learning_rate: 0.0010
# Epoch 13/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 520.7859 - mae: 520.6590 - val_loss: 441.1768 - val_mae: 441.0567 - learning_rate: 0.0010
# Epoch 14/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 501.3664 - mae: 501.2519 - val_loss: 442.2698 - val_mae: 442.1624 - learning_rate: 0.0010
# Epoch 15/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 523.1971 - mae: 523.0935 - val_loss: 440.7448 - val_mae: 440.6479 - learning_rate: 0.0010
# Epoch 16/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 503.1684 - mae: 503.0739 - val_loss: 436.9601 - val_mae: 436.8727 - learning_rate: 0.0010
# Epoch 17/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 486.1649 - mae: 486.0792 - val_loss: 432.7653 - val_mae: 432.6856 - learning_rate: 0.0010
# Epoch 18/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 483.9472 - mae: 483.8692 - val_loss: 430.6586 - val_mae: 430.5851 - learning_rate: 0.0010
# Epoch 19/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 496.0518 - mae: 495.9800 - val_loss: 423.7062 - val_mae: 423.6404 - learning_rate: 0.0010
# Epoch 20/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 472.1156 - mae: 472.0513 - val_loss: 421.6173 - val_mae: 421.5589 - learning_rate: 0.0010
# Epoch 21/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 494.5705 - mae: 494.5133 - val_loss: 416.4931 - val_mae: 416.4405 - learning_rate: 0.0010
# Epoch 22/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 464.3279 - mae: 464.2760 - val_loss: 413.7522 - val_mae: 413.7010 - learning_rate: 0.0010
# Epoch 23/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 470.9068 - mae: 470.8559 - val_loss: 410.8722 - val_mae: 410.8235 - learning_rate: 0.0010
# Epoch 24/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 481.0052 - mae: 480.9571 - val_loss: 407.8839 - val_mae: 407.8369 - learning_rate: 0.0010
# Epoch 25/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 468.0213 - mae: 467.9753 - val_loss: 405.4136 - val_mae: 405.3650 - learning_rate: 0.0010
# Epoch 26/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 468.4282 - mae: 468.3824 - val_loss: 402.2502 - val_mae: 402.2058 - learning_rate: 0.0010
# Epoch 27/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 467.5534 - mae: 467.5097 - val_loss: 397.7788 - val_mae: 397.7376 - learning_rate: 0.0010
# Epoch 28/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 468.4643 - mae: 468.4238 - val_loss: 394.9508 - val_mae: 394.9140 - learning_rate: 0.0010
# Epoch 29/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 462.7756 - mae: 462.7398 - val_loss: 391.8213 - val_mae: 391.7899 - learning_rate: 0.0010
# Epoch 30/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 438.6873 - mae: 438.6563 - val_loss: 386.7296 - val_mae: 386.6999 - learning_rate: 0.0010
# Epoch 31/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 447.1509 - mae: 447.1223 - val_loss: 379.7173 - val_mae: 379.6902 - learning_rate: 0.0010
# Epoch 32/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 456.0226 - mae: 455.9964 - val_loss: 375.8409 - val_mae: 375.8146 - learning_rate: 0.0010
# Epoch 33/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 436.0202 - mae: 435.9931 - val_loss: 365.8736 - val_mae: 365.8467 - learning_rate: 0.0010
# Epoch 34/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 440.0770 - mae: 440.0510 - val_loss: 362.3178 - val_mae: 362.2938 - learning_rate: 0.0010
# Epoch 35/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 414.4567 - mae: 414.4330 - val_loss: 359.6449 - val_mae: 359.6223 - learning_rate: 0.0010
# Epoch 36/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 423.8965 - mae: 423.8723 - val_loss: 356.0683 - val_mae: 356.0472 - learning_rate: 0.0010
# Epoch 37/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 443.9143 - mae: 443.8950 - val_loss: 354.1451 - val_mae: 354.1281 - learning_rate: 0.0010
# Epoch 38/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 423.2381 - mae: 423.2210 - val_loss: 352.2820 - val_mae: 352.2670 - learning_rate: 0.0010
# Epoch 39/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 403.8662 - mae: 403.8508 - val_loss: 347.7409 - val_mae: 347.7270 - learning_rate: 0.0010
# Epoch 40/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 418.9166 - mae: 418.9028 - val_loss: 344.2630 - val_mae: 344.2484 - learning_rate: 0.0010
# Epoch 41/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 419.4846 - mae: 419.4691 - val_loss: 337.6739 - val_mae: 337.6554 - learning_rate: 0.0010
# Epoch 42/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 393.9225 - mae: 393.9047 - val_loss: 334.9290 - val_mae: 334.9095 - learning_rate: 0.0010
# Epoch 43/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 403.8637 - mae: 403.8450 - val_loss: 333.1636 - val_mae: 333.1443 - learning_rate: 0.0010
# Epoch 44/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 375.4787 - mae: 375.4590 - val_loss: 331.9886 - val_mae: 331.9691 - learning_rate: 0.0010
# Epoch 45/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 383.0256 - mae: 383.0053 - val_loss: 328.7141 - val_mae: 328.6927 - learning_rate: 0.0010
# Epoch 46/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 388.8694 - mae: 388.8468 - val_loss: 324.0184 - val_mae: 323.9907 - learning_rate: 0.0010
# Epoch 47/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 356.9062 - mae: 356.8785 - val_loss: 317.3169 - val_mae: 317.2877 - learning_rate: 0.0010
# Epoch 48/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 381.3017 - mae: 381.2728 - val_loss: 311.6329 - val_mae: 311.6031 - learning_rate: 0.0010
# Epoch 49/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 358.3756 - mae: 358.3457 - val_loss: 309.8042 - val_mae: 309.7748 - learning_rate: 0.0010
# Epoch 50/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 355.2019 - mae: 355.1730 - val_loss: 307.9742 - val_mae: 307.9457 - learning_rate: 0.0010
# Epoch 51/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 363.9778 - mae: 363.9500 - val_loss: 303.6786 - val_mae: 303.6527 - learning_rate: 0.0010
# Epoch 52/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 343.8360 - mae: 343.8105 - val_loss: 301.6902 - val_mae: 301.6660 - learning_rate: 0.0010
# Epoch 53/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 355.2051 - mae: 355.1795 - val_loss: 300.4163 - val_mae: 300.3935 - learning_rate: 0.0010
# Epoch 54/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 348.8192 - mae: 348.7962 - val_loss: 300.4258 - val_mae: 300.4040 - learning_rate: 0.0010
# Epoch 55/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 357.3063 - mae: 357.2836 - val_loss: 299.2718 - val_mae: 299.2459 - learning_rate: 0.0010
# Epoch 56/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 334.6147 - mae: 334.5883 - val_loss: 295.6171 - val_mae: 295.5881 - learning_rate: 0.0010
# Epoch 57/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 333.1926 - mae: 333.1629 - val_loss: 287.9827 - val_mae: 287.9519 - learning_rate: 0.0010
# Epoch 58/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 330.1902 - mae: 330.1588 - val_loss: 282.1454 - val_mae: 282.1118 - learning_rate: 0.0010
# Epoch 59/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 315.6358 - mae: 315.6002 - val_loss: 279.8904 - val_mae: 279.8482 - learning_rate: 0.0010
# Epoch 60/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 317.5956 - mae: 317.5541 - val_loss: 277.0122 - val_mae: 276.9662 - learning_rate: 0.0010
# Epoch 61/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 328.3978 - mae: 328.3496 - val_loss: 275.5856 - val_mae: 275.5310 - learning_rate: 0.0010
# Epoch 62/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 311.6229 - mae: 311.5665 - val_loss: 271.7862 - val_mae: 271.7257 - learning_rate: 0.0010
# Epoch 63/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 304.6677 - mae: 304.6056 - val_loss: 267.2289 - val_mae: 267.1602 - learning_rate: 0.0010
# Epoch 64/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 300.3640 - mae: 300.2918 - val_loss: 265.6521 - val_mae: 265.5755 - learning_rate: 0.0010
# Epoch 65/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 307.0382 - mae: 306.9603 - val_loss: 263.8937 - val_mae: 263.8090 - learning_rate: 0.0010
# Epoch 66/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 310.7914 - mae: 310.7051 - val_loss: 262.3900 - val_mae: 262.2979 - learning_rate: 0.0010
# Epoch 67/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 293.6387 - mae: 293.5435 - val_loss: 261.1905 - val_mae: 261.0910 - learning_rate: 0.0010
# Epoch 68/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 309.0531 - mae: 308.9510 - val_loss: 261.5697 - val_mae: 261.4626 - learning_rate: 0.0010
# Epoch 69/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 306.4102 - mae: 306.3015 - val_loss: 262.4025 - val_mae: 262.2902 - learning_rate: 0.0010
# Epoch 70/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 307.0569 - mae: 306.9432 - val_loss: 261.6425 - val_mae: 261.5262 - learning_rate: 0.0010
# Epoch 71/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 291.8728 - mae: 291.7558 - val_loss: 259.9290 - val_mae: 259.8109 - learning_rate: 0.0010
# Epoch 72/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 293.0110 - mae: 292.8918 - val_loss: 259.3920 - val_mae: 259.2735 - learning_rate: 0.0010
# Epoch 73/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 285.6335 - mae: 285.5146 - val_loss: 258.7632 - val_mae: 258.6433 - learning_rate: 0.0010
# Epoch 74/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 289.9734 - mae: 289.8513 - val_loss: 255.3961 - val_mae: 255.2722 - learning_rate: 0.0010
# Epoch 75/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 276.8258 - mae: 276.7007 - val_loss: 260.3920 - val_mae: 260.2657 - learning_rate: 0.0010
# Epoch 76/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 286.0782 - mae: 285.9511 - val_loss: 258.3354 - val_mae: 258.2057 - learning_rate: 0.0010
# Epoch 77/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 280.9341 - mae: 280.8051 - val_loss: 257.6280 - val_mae: 257.4961 - learning_rate: 0.0010
# Epoch 78/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 267.2480 - mae: 267.1169 - val_loss: 256.7349 - val_mae: 256.6038 - learning_rate: 0.0010
# Epoch 79/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 270.7683 - mae: 270.6366 - val_loss: 255.5232 - val_mae: 255.3900 - learning_rate: 0.0010
# Epoch 80/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 270.0248 - mae: 269.8899 - val_loss: 254.8427 - val_mae: 254.7106 - learning_rate: 5.0000e-04
# Epoch 81/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 268.7610 - mae: 268.6290 - val_loss: 254.4139 - val_mae: 254.2822 - learning_rate: 5.0000e-04
# Epoch 82/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 277.6920 - mae: 277.5603 - val_loss: 253.8816 - val_mae: 253.7509 - learning_rate: 5.0000e-04
# Epoch 83/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 275.8732 - mae: 275.7425 - val_loss: 253.2625 - val_mae: 253.1332 - learning_rate: 5.0000e-04
# Epoch 84/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 269.1221 - mae: 268.9925 - val_loss: 253.0345 - val_mae: 252.9057 - learning_rate: 5.0000e-04
# Epoch 85/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 272.8332 - mae: 272.7044 - val_loss: 254.8098 - val_mae: 254.6816 - learning_rate: 5.0000e-04
# Epoch 86/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 265.7844 - mae: 265.6565 - val_loss: 253.2728 - val_mae: 253.1458 - learning_rate: 5.0000e-04
# Epoch 87/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 265.1311 - mae: 265.0043 - val_loss: 252.1594 - val_mae: 252.0336 - learning_rate: 5.0000e-04
# Epoch 88/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 271.3814 - mae: 271.2556 - val_loss: 251.6577 - val_mae: 251.5328 - learning_rate: 5.0000e-04
# Epoch 89/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 253.7688 - mae: 253.6437 - val_loss: 251.0949 - val_mae: 250.9698 - learning_rate: 5.0000e-04
# Epoch 90/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 260.3227 - mae: 260.1978 - val_loss: 249.3481 - val_mae: 249.2230 - learning_rate: 5.0000e-04
# Epoch 91/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 267.6834 - mae: 267.5579 - val_loss: 246.8874 - val_mae: 246.7612 - learning_rate: 5.0000e-04
# Epoch 92/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 263.4144 - mae: 263.2884 - val_loss: 248.0571 - val_mae: 247.9318 - learning_rate: 5.0000e-04
# Epoch 93/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 264.8570 - mae: 264.7314 - val_loss: 250.1004 - val_mae: 249.9750 - learning_rate: 5.0000e-04
# Epoch 94/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 264.0893 - mae: 263.9637 - val_loss: 251.3742 - val_mae: 251.2483 - learning_rate: 5.0000e-04
# Epoch 95/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 255.2429 - mae: 255.1167 - val_loss: 247.9231 - val_mae: 247.7956 - learning_rate: 5.0000e-04
# Epoch 96/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 244.4506 - mae: 244.3223 - val_loss: 240.2011 - val_mae: 240.0691 - learning_rate: 5.0000e-04
# Epoch 97/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 252.0401 - mae: 251.9065 - val_loss: 237.4226 - val_mae: 237.2837 - learning_rate: 5.0000e-04
# Epoch 98/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 239.7905 - mae: 239.6499 - val_loss: 235.4593 - val_mae: 235.3172 - learning_rate: 5.0000e-04
# Epoch 99/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 219.3772 - mae: 219.2339 - val_loss: 230.3288 - val_mae: 230.1853 - learning_rate: 5.0000e-04
# Epoch 100/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 227.5150 - mae: 227.3705 - val_loss: 230.1188 - val_mae: 229.9723 - learning_rate: 5.0000e-04
# Epoch 101/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 221.3572 - mae: 221.2088 - val_loss: 222.7694 - val_mae: 222.6213 - learning_rate: 5.0000e-04
# Epoch 102/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 218.7055 - mae: 218.5568 - val_loss: 202.0100 - val_mae: 201.8600 - learning_rate: 5.0000e-04
# Epoch 103/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 222.7599 - mae: 222.6109 - val_loss: 202.6846 - val_mae: 202.5319 - learning_rate: 5.0000e-04
# Epoch 104/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 211.7930 - mae: 211.6427 - val_loss: 215.9337 - val_mae: 215.7848 - learning_rate: 5.0000e-04
# Epoch 105/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 225.6752 - mae: 225.5249 - val_loss: 184.0862 - val_mae: 183.9291 - learning_rate: 5.0000e-04
# Epoch 106/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 219.2061 - mae: 219.0541 - val_loss: 193.7779 - val_mae: 193.6268 - learning_rate: 5.0000e-04
# Epoch 107/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 198.5995 - mae: 198.4477 - val_loss: 184.6232 - val_mae: 184.4708 - learning_rate: 5.0000e-04
# Epoch 108/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 230.7968 - mae: 230.6443 - val_loss: 200.6231 - val_mae: 200.4657 - learning_rate: 5.0000e-04
# Epoch 109/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 209.1093 - mae: 208.9523 - val_loss: 171.6770 - val_mae: 171.5181 - learning_rate: 5.0000e-04
# Epoch 110/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 192.7927 - mae: 192.6357 - val_loss: 175.2789 - val_mae: 175.1192 - learning_rate: 5.0000e-04
# Epoch 111/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 205.6761 - mae: 205.5179 - val_loss: 155.4542 - val_mae: 155.2972 - learning_rate: 5.0000e-04
# Epoch 112/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 198.7904 - mae: 198.6332 - val_loss: 190.3231 - val_mae: 190.1660 - learning_rate: 5.0000e-04
# Epoch 113/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 194.9046 - mae: 194.7464 - val_loss: 221.9088 - val_mae: 221.7518 - learning_rate: 5.0000e-04
# Epoch 114/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 214.6258 - mae: 214.4684 - val_loss: 145.3852 - val_mae: 145.2272 - learning_rate: 5.0000e-04
# Epoch 115/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 191.2365 - mae: 191.0778 - val_loss: 187.3586 - val_mae: 187.1998 - learning_rate: 5.0000e-04
# Epoch 116/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 187.3618 - mae: 187.2026 - val_loss: 201.0708 - val_mae: 200.9114 - learning_rate: 5.0000e-04
# Epoch 117/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 193.1178 - mae: 192.9585 - val_loss: 140.4420 - val_mae: 140.2822 - learning_rate: 5.0000e-04
# Epoch 118/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 194.3234 - mae: 194.1638 - val_loss: 140.7527 - val_mae: 140.5933 - learning_rate: 5.0000e-04
# Epoch 119/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 185.2609 - mae: 185.1016 - val_loss: 148.2158 - val_mae: 148.0560 - learning_rate: 5.0000e-04
# Epoch 120/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 196.9775 - mae: 196.8171 - val_loss: 158.4619 - val_mae: 158.3017 - learning_rate: 5.0000e-04
# Epoch 121/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 186.1743 - mae: 186.0131 - val_loss: 135.8794 - val_mae: 135.7166 - learning_rate: 5.0000e-04
# Epoch 122/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 193.2037 - mae: 193.0422 - val_loss: 135.3826 - val_mae: 135.2205 - learning_rate: 5.0000e-04
# Epoch 123/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 184.4544 - mae: 184.2918 - val_loss: 146.7045 - val_mae: 146.5396 - learning_rate: 5.0000e-04
# Epoch 124/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 168.1647 - mae: 168.0034 - val_loss: 130.4286 - val_mae: 130.2670 - learning_rate: 5.0000e-04
# Epoch 125/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 177.0424 - mae: 176.8805 - val_loss: 123.7785 - val_mae: 123.6158 - learning_rate: 5.0000e-04
# Epoch 126/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 191.0992 - mae: 190.9333 - val_loss: 145.5134 - val_mae: 145.3498 - learning_rate: 5.0000e-04
# Epoch 127/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 173.9467 - mae: 173.7815 - val_loss: 201.1967 - val_mae: 201.0325 - learning_rate: 5.0000e-04
# Epoch 128/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 185.3953 - mae: 185.2299 - val_loss: 120.8178 - val_mae: 120.6537 - learning_rate: 5.0000e-04
# Epoch 129/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 176.5774 - mae: 176.4129 - val_loss: 140.0993 - val_mae: 139.9326 - learning_rate: 5.0000e-04
# Epoch 130/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 166.9872 - mae: 166.8198 - val_loss: 134.5997 - val_mae: 134.4323 - learning_rate: 5.0000e-04
# Epoch 131/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 173.3080 - mae: 173.1408 - val_loss: 202.3160 - val_mae: 202.1482 - learning_rate: 5.0000e-04
# Epoch 132/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 183.3633 - mae: 183.1949 - val_loss: 126.2365 - val_mae: 126.0680 - learning_rate: 5.0000e-04
# Epoch 133/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 170.8041 - mae: 170.6355 - val_loss: 198.2840 - val_mae: 198.1138 - learning_rate: 5.0000e-04
# Epoch 134/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 174.6662 - mae: 174.4979 - val_loss: 123.0349 - val_mae: 122.8647 - learning_rate: 2.5000e-04
# Epoch 135/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 168.5610 - mae: 168.3929 - val_loss: 116.8005 - val_mae: 116.6325 - learning_rate: 2.5000e-04
# Epoch 136/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 163.2294 - mae: 163.0616 - val_loss: 134.2625 - val_mae: 134.0954 - learning_rate: 2.5000e-04
# Epoch 137/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 163.9379 - mae: 163.7701 - val_loss: 121.4670 - val_mae: 121.3002 - learning_rate: 2.5000e-04
# Epoch 138/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 166.7013 - mae: 166.5339 - val_loss: 128.5368 - val_mae: 128.3702 - learning_rate: 2.5000e-04
# Epoch 139/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 165.3773 - mae: 165.2107 - val_loss: 136.3004 - val_mae: 136.1347 - learning_rate: 2.5000e-04
# Epoch 140/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 160.7456 - mae: 160.5800 - val_loss: 154.7736 - val_mae: 154.6079 - learning_rate: 2.5000e-04
# Epoch 141/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 170.8684 - mae: 170.7043 - val_loss: 111.6055 - val_mae: 111.4415 - learning_rate: 1.2500e-04
# Epoch 142/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 161.4613 - mae: 161.2950 - val_loss: 116.2681 - val_mae: 116.1044 - learning_rate: 1.2500e-04
# Epoch 143/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 162.3588 - mae: 162.1947 - val_loss: 109.7826 - val_mae: 109.6161 - learning_rate: 1.2500e-04
# Epoch 144/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 158.6848 - mae: 158.5198 - val_loss: 110.7062 - val_mae: 110.5429 - learning_rate: 1.2500e-04
# Epoch 145/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 167.8612 - mae: 167.6980 - val_loss: 143.8304 - val_mae: 143.6674 - learning_rate: 1.2500e-04
# Epoch 146/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 160.9801 - mae: 160.8168 - val_loss: 106.5678 - val_mae: 106.4033 - learning_rate: 1.2500e-04
# Epoch 147/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 163.8517 - mae: 163.6879 - val_loss: 107.2464 - val_mae: 107.0822 - learning_rate: 1.2500e-04
# Epoch 148/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 168.0613 - mae: 167.8980 - val_loss: 107.5217 - val_mae: 107.3571 - learning_rate: 1.2500e-04
# Epoch 149/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 157.3219 - mae: 157.1595 - val_loss: 126.5977 - val_mae: 126.4361 - learning_rate: 1.2500e-04
# Epoch 150/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 161.8995 - mae: 161.7378 - val_loss: 107.4157 - val_mae: 107.2524 - learning_rate: 1.2500e-04
# Epoch 151/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 163.9762 - mae: 163.8147 - val_loss: 116.7036 - val_mae: 116.5378 - learning_rate: 1.2500e-04
# Epoch 152/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 156.6393 - mae: 156.4776 - val_loss: 109.0081 - val_mae: 108.8471 - learning_rate: 6.2500e-05
# Epoch 153/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 157.3092 - mae: 157.1483 - val_loss: 115.2640 - val_mae: 115.1027 - learning_rate: 6.2500e-05
# Epoch 154/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 155.6227 - mae: 155.4606 - val_loss: 109.0855 - val_mae: 108.9244 - learning_rate: 6.2500e-05
# Epoch 155/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 169.0369 - mae: 168.8759 - val_loss: 111.4982 - val_mae: 111.3382 - learning_rate: 6.2500e-05
# Epoch 156/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 153.8391 - mae: 153.6790 - val_loss: 119.4195 - val_mae: 119.2597 - learning_rate: 6.2500e-05
# Epoch 157/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 162.4891 - mae: 162.3267 - val_loss: 110.5510 - val_mae: 110.3883 - learning_rate: 3.1250e-05
# Epoch 158/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 160.2998 - mae: 160.1398 - val_loss: 110.5466 - val_mae: 110.3847 - learning_rate: 3.1250e-05
# Epoch 159/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 158.8645 - mae: 158.7029 - val_loss: 109.6259 - val_mae: 109.4651 - learning_rate: 3.1250e-05
# Epoch 160/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 167.2583 - mae: 167.0987 - val_loss: 111.8739 - val_mae: 111.7146 - learning_rate: 3.1250e-05
# Epoch 161/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 162.2169 - mae: 162.0573 - val_loss: 108.2409 - val_mae: 108.0800 - learning_rate: 3.1250e-05
# Epoch 162/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 155.0526 - mae: 154.8927 - val_loss: 111.0177 - val_mae: 110.8560 - learning_rate: 1.5625e-05
# Epoch 163/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 157.2957 - mae: 157.1355 - val_loss: 108.7788 - val_mae: 108.6187 - learning_rate: 1.5625e-05
# Epoch 164/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 167.4231 - mae: 167.2634 - val_loss: 110.8168 - val_mae: 110.6578 - learning_rate: 1.5625e-05
# Epoch 165/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 153.8546 - mae: 153.6954 - val_loss: 108.3193 - val_mae: 108.1552 - learning_rate: 1.5625e-05
# Epoch 166/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 159.0083 - mae: 158.8475 - val_loss: 108.4979 - val_mae: 108.3391 - learning_rate: 1.5625e-05

# %%
model.save("credit_score_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        1000 non-null   int64
#  1   Gender                     1000 non-null   int64
#  2   Marital Status             1000 non-null   float64
#  3   Education Level            1000 non-null   int64
#  4   Employment Status          1000 non-null   int64
#  5   Credit Utilization Ratio   1000 non-null   float64
#  6   Payment History            1000 non-null   float64
#  7   Number of Credit Accounts  1000 non-null   int64
#  8   Loan Amount                1000 non-null   int64
#  9   Interest Rate              1000 non-null   float64
#  10  Loan Term                  1000 non-null   int64
#  11  Type of Loan               1000 non-null   int64
# dtypes: float64(4), int64(8)
# memory usage: 93.9 KB

# %%
data.head()
# Out:
#    Age  Gender  Marital Status  Education Level  Employment Status  \
# 0   60       1             1.0                3                  1
# 1   25       1             1.0                1                  0
# 2   30       0             0.0                3                  1
# 3   58       0             1.0                4                  0
# 4   32       1             1.0                2                  2
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      22.0           2685.0                          2
# 1                      20.0           2371.0                          9
# 2                      22.0           2771.0                          6
# 3                      12.0           1371.0                          2
# 4                      99.0            828.0                          2
#
#    Loan Amount  Interest Rate  Loan Term  Type of Loan  Credit Score
# 0      4675000           2.65         48             1       940.516
# 1      3619000           5.19         60             2       831.360
# 2       957000           2.76         12             2       971.216
# 3      4731000           6.57         60             2       480.586
# 4      3289000           6.28         36             1       290.797
